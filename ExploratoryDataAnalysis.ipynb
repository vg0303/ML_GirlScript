# %% [markdown]
# <a href="https://colab.research.google.com/github/vg0303/ML_GirlScript/blob/main/ExploratoryDataAnalysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Exploratory Data Analysis
#
# Date created: 12/06/21
#
# [For downloading the dataset, click here](https://archive.ics.uci.edu/ml/datasets/Student+Performance)
#
# We are training the model to predict the final grade i.e. G3
# and we will be spliting the data in 80-20 format for training and testing

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd '/content/drive/MyDrive/ML_Colab/EDA/student'
# Out:
# /content/drive/MyDrive/ML_Colab/EDA/student

# %%
ls
# Out:
# 'student-mat (1).gsheet'   student-mat.gsheet   student-por.csv
#  student-mat.csv           student-merge.R      student.txt

# %% [markdown]
# Importing the necessary libraries

# %%
import pandas as pd                 #working with csv or excel files
import numpy as np                  #working with numbers/ arrays/ tensors
import tensorflow as tf             #framework
from tensorflow import keras        #API / library 
import os                           #using os commands between the python language

# %% [markdown]
# **To load the data we have,**
#
# **mathData** is just a variable name that we have chosen, we are assigning it with the data file. Now we can use this variable everytime we need to access the data file.
#
# To understand the meaning of the columns, or the types of values accpeted by that column, check out the **txt file**, it has the description of the input types.

# %%
mathData = pd.read_csv('student-mat.csv', sep=';') 
#load the csv file as dataframe and "sep" is used to separate the columns as in the text file, data is separated by ";"

# %%
mathData.tail(10) 
#default is the number 5 if you dont specify anything
#prints 10 rows from bottom
# Out:
#     school sex  age address famsize Pstatus  ...  Walc  health absences  G1  G2  G3
# 385     MS   F   18       R     GT3       T  ...     3       4        2  10   9  10
# 386     MS   F   18       R     GT3       T  ...     2       5        7   6   5   6
# 387     MS   F   19       R     GT3       T  ...     2       5        0   7   5   0
# 388     MS   F   18       U     LE3       T  ...     1       1        0   7   9   8
# 389     MS   F   18       U     GT3       T  ...     1       5        0   6   5   0
# 390     MS   M   20       U     LE3       A  ...     5       4       11   9   9   9
# 391     MS   M   17       U     LE3       T  ...     4       2        3  14  16  16
# 392     MS   M   21       R     GT3       T  ...     3       3        3  10   8   7
# 393     MS   M   18       R     LE3       T  ...     4       5        0  11  12  10
# 394     MS   M   19       U     LE3       T  ...     3       5        5   8   9   9
#
# [10 rows x 33 columns]

# %%
mathData.head(10) 
#print the first ten rows of the dataframe
#prints 10 rows from top
# Out:
#   school sex  age address famsize Pstatus  ...  Walc  health absences  G1  G2  G3
# 0     GP   F   18       U     GT3       A  ...     1       3        6   5   6   6
# 1     GP   F   17       U     GT3       T  ...     1       3        4   5   5   6
# 2     GP   F   15       U     LE3       T  ...     3       3       10   7   8  10
# 3     GP   F   15       U     GT3       T  ...     1       5        2  15  14  15
# 4     GP   F   16       U     GT3       T  ...     2       5        4   6  10  10
# 5     GP   M   16       U     LE3       T  ...     2       5       10  15  15  15
# 6     GP   M   16       U     LE3       T  ...     1       3        0  12  12  11
# 7     GP   F   17       U     GT3       A  ...     1       1        6   6   5   6
# 8     GP   M   15       U     LE3       A  ...     1       1        0  16  18  19
# 9     GP   M   15       U     GT3       T  ...     1       5        0  14  15  15
#
# [10 rows x 33 columns]

# %% [markdown]
# #Data Processing
#
# For the model to work we need to convert the categorical data into numerical data so that it can worked upon.
#
# For doing that we need to first find out all the possible unique values for every column present in the data file. Use the below code to find out.

# %%
#unique classes/categories in every column 

# variable.column.unique() --> all {column} values from the {variable} dataframe and print out the unique ones. 


print(f'school: {mathData.school.unique()}')
print(f'sex: {mathData.sex.unique()}')
print(f'address: {mathData.address.unique()}')
print(f'Mjob: {mathData.Mjob.unique()}')
print(f'Fjob: {mathData.Fjob.unique()}')
print(f'higher: {mathData.higher.unique()}')
# Out:
# school: ['GP' 'MS']
# sex: ['F' 'M']
# address: ['U' 'R']
# Mjob: ['at_home' 'health' 'other' 'services' 'teacher']
# Fjob: ['teacher' 'other' 'services' 'health' 'at_home']
# higher: ['yes' 'no']

# %% [markdown]
# Considering the
#
# `mathData['school'] = mathData['school'].apply({'GP':1, 'MS':2}.get)`
#
# over the whole column "school" **apply** the numrical values which you will **get** from the dictionary
#
# Access the column school from the variable mathData (which has the pandas dataframe).
#
# Once we access it, since we are using a dictionary we will replace the string / categorical values with numeric data.
#
# Meaning -->
#
# 1.   Replace GP with 1
# 2.   Replace MS with 2
#
# NOTE:
# You can have 1 or 0 for binary but never start from 0 for multiclasses/multiple categories, instead go like 1,2,..

# %%
#convert the categories into numbers 

#binary valued 

mathData['school'] = mathData['school'].apply({'GP':1, 'MS':2}.get)
mathData['sex'] = mathData['sex'].apply({'F':1, 'M':2}.get)
mathData['address'] = mathData['address'].apply({'U':1, 'R':2}.get)
mathData['higher'] = mathData['higher'].apply({'yes':1, 'no':2}.get)


#multi-valued
mathData['Mjob'] = mathData['Mjob'].apply({'at_home':1, 'health':2, 'other':3, 'services':4, 'teacher':5}.get)
mathData['Fjob'] = mathData['Fjob'].apply({'at_home':1, 'health':2, 'other':3, 'services':4, 'teacher':5}.get)

mathData.head(20)
# Out:
#     school  sex  age  address famsize  ... health  absences  G1  G2  G3
# 0        1    1   18        1     GT3  ...      3         6   5   6   6
# 1        1    1   17        1     GT3  ...      3         4   5   5   6
# 2        1    1   15        1     LE3  ...      3        10   7   8  10
# 3        1    1   15        1     GT3  ...      5         2  15  14  15
# 4        1    1   16        1     GT3  ...      5         4   6  10  10
# 5        1    2   16        1     LE3  ...      5        10  15  15  15
# 6        1    2   16        1     LE3  ...      3         0  12  12  11
# 7        1    1   17        1     GT3  ...      1         6   6   5   6
# 8        1    2   15        1     LE3  ...      1         0  16  18  19
# 9        1    2   15        1     GT3  ...      5         0  14  15  15
# 10       1    1   15        1     GT3  ...      2         0  10   8   9
# 11       1    1   15        1     GT3  ...      4         4  10  12  12
# ...

# %%
#consider the below columns from the DataFrame
#all of these have numeric values

mathData = mathData[['school', 'sex', 'address', 'Mjob', 'Fjob', 'higher', 'freetime', 'studytime', 'absences', 'G1', 'G2', 'G3']]

# %%
mathData.head(10)
# Out:
#    school  sex  address  Mjob  Fjob  ...  studytime  absences  G1  G2  G3
# 0       1    1        1     1     5  ...          2         6   5   6   6
# 1       1    1        1     1     3  ...          2         4   5   5   6
# 2       1    1        1     1     3  ...          2        10   7   8  10
# 3       1    1        1     2     4  ...          3         2  15  14  15
# 4       1    1        1     3     3  ...          2         4   6  10  10
# 5       1    2        1     4     3  ...          2        10  15  15  15
# 6       1    2        1     3     3  ...          2         0  12  12  11
# 7       1    1        1     3     5  ...          2         6   6   5   6
# 8       1    2        1     4     3  ...          2         0  16  18  19
# 9       1    2        1     3     3  ...          2         0  14  15  15
#
# [10 rows x 12 columns]

# %%
#save the clean table in another csv file
#export the mathData as cleanedMathData as csv file [sep=',']
mathData.to_csv('cleanedMathData.csv')

# %%
ls
# Out:
#  cleanedMathData.csv       student-mat.csv      student-merge.R   student.txt
# 'student-mat (1).gsheet'   student-mat.gsheet   student-por.csv

# %% [markdown]
# #Data Visualization

# %% [markdown]
# **Seaborn**: is a Python data visualization library based on **matplotlib**. It provides a high-level interface for drawing attractive and informative statistical graphics
#
# **palplot**: Plot the values in a color palette as a horizontal array.
#
# **matplotlib**: Matplotlib is a comprehensive library for creating static, animated, and interactive visualizations in Python.
#
# **pyplot**: Most of the Matplotlib utilities lies under the pyplot submodule, and are usually imported under the plt alias

# %%
import seaborn as sns
sns.palplot(sns.color_palette('PuOr')) #Purple to Orange colors
pal = sns.color_palette('PuOr', 6) #print 6 color shades from Purple to Orange
pal.as_hex() #set hex code values for colors

import matplotlib.pyplot as plt
plt.style.use(['seaborn'])
sns_colors = ['#c6690c', '#664697'] #orange Purple hex codes
sns.set_palette(sns_colors) #set the palette as sns_colors 
sns.palplot(sns.color_palette(sns_colors)) #plot the color codes

# %%
print(f'''There are {len(mathData.columns)} columns in the dataframe mathData namely,

{mathData.columns}''') #columns in the dataframe
# Out:
# There are 12 columns in the dataframe mathData namely,
#
# Index(['school', 'sex', 'address', 'Mjob', 'Fjob', 'higher', 'freetime',
#        'studytime', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %% [markdown]
# A **pairplot** is a plot where the x axis and y axis will have all the columns you specify it with.

# %%
sns.pairplot(mathData,
             x_vars = [ 'G3', 'freetime', 'studytime', 'absences' ],
             y_vars = ['G1', 'G2', 'G3'],
       diag_kind='kde', hue='G3'
             )
#the "hue" attribute is adding colour in the graph according to the value, if the value is high, its dark purple etc
#we have used G3 as the reference for the num for the hue.
#kde is a kind of a graph with dots for each value.
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
# ...

# %%
#pairplot for all the values

sns.pairplot(mathData,
             x_vars = ['school', 'sex', 'address', 'Mjob', 'Fjob', 'higher', 'freetime',
       'studytime', 'absences', 'G1', 'G2'],
             y_vars = ['school', 'sex', 'address', 'Mjob', 'Fjob', 'higher', 'freetime',
       'studytime', 'absences', 'G1', 'G2' ],
       diag_kind='kde', hue='G3'
             )
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
# ...

# %%
#stripplot --> Plotting a graph
sns.stripplot(y='G1', x='G2', data=mathData)

# %%
#Plotting mulitple graphs together
# stripplots plotted as subplots on one main plot with the ax parameter

fig, axarr = plt.subplots(3,2, figsize=(10,10))

#three rows and 2 columns all starting from (0,0)

sns.stripplot(y='G1', x='G2', data=mathData, hue=None, ax=axarr[0][0])
sns.stripplot(y='G1', x='G3', data=mathData, hue=None, ax=axarr[1][1])
sns.stripplot(y='studytime', x='G3', data=mathData, hue=None, ax=axarr[1][0])
sns.stripplot(y='freetime', x='G3', data=mathData, hue=None,  ax=axarr[0][1])
sns.stripplot(y='higher', x='G3', data=mathData, hue=None, ax=axarr[2][0])
sns.stripplot(y='absences', x='G3', data=mathData, hue=None, ax=axarr[2][1])

# %% [markdown]
# #Data Splits

# %%
#80-20 train-test percent split

trainDataset = mathData.sample(frac=0.8, random_state=0) 
testDataset = mathData.drop(trainDataset.index)

print(trainDataset.head())
print(testDataset.head())
# Out:
#      school  sex  address  Mjob  Fjob  ...  studytime  absences  G1  G2  G3
# 329       1    1        1     5     5  ...          3         4  14  14  14
# 318       1    1        2     1     4  ...          3         0  11  11  10
# 317       1    1        1     3     3  ...          3         9   9  10   9
# 65        1    1        1     5     4  ...          2         2  16  15  15
# 59        1    1        1     4     3  ...          2         2  15  16  16
#
# [5 rows x 12 columns]
#     school  sex  address  Mjob  Fjob  ...  studytime  absences  G1  G2  G3
# 9        1    2        1     3     3  ...          2         0  14  15  15
# 25       1    1        1     4     4  ...          1        14   6   9   8
# 28       1    2        1     4     3  ...          2         4  11  11  11
# 31       1    2        1     4     4  ...          2         0  17  16  17
# 32       1    2        2     5     1  ...          2         0  17  16  16
#
# [5 rows x 12 columns]

# %%
print(trainDataset.shape)
print(testDataset.shape)
#(rows,col)
# Out:
# (316, 12)
# (79, 12)

# %%
#copy the trainDataset dataframe for getting the features

trainFeatures = trainDataset.copy()
testFeatures = testDataset.copy()

print(trainFeatures.head())
print(testFeatures.head())
# Out:
#      school  sex  address  Mjob  Fjob  ...  studytime  absences  G1  G2  G3
# 329       1    1        1     5     5  ...          3         4  14  14  14
# 318       1    1        2     1     4  ...          3         0  11  11  10
# 317       1    1        1     3     3  ...          3         9   9  10   9
# 65        1    1        1     5     4  ...          2         2  16  15  15
# 59        1    1        1     4     3  ...          2         2  15  16  16
#
# [5 rows x 12 columns]
#     school  sex  address  Mjob  Fjob  ...  studytime  absences  G1  G2  G3
# 9        1    2        1     3     3  ...          2         0  14  15  15
# 25       1    1        1     4     4  ...          1        14   6   9   8
# 28       1    2        1     4     3  ...          2         4  11  11  11
# 31       1    2        1     4     4  ...          2         0  17  16  17
# 32       1    2        2     5     1  ...          2         0  17  16  16
#
# [5 rows x 12 columns]

# %%
#removing the G3 column and saving it into the labels variable

trainLabels = trainFeatures.pop('G3')
testLabels = testFeatures.pop('G3')

print(trainLabels.head())
print(testLabels.head())
# Out:
# 329    14
# 318    10
# 317     9
# 65     15
# 59     16
# Name: G3, dtype: int64
# 9     15
# 25     8
# 28    11
# 31    17
# 32    16
# Name: G3, dtype: int64

# %%
print(trainFeatures.head())
print(testFeatures.head())
# Out:
#      school  sex  address  Mjob  Fjob  ...  freetime  studytime  absences  G1  G2
# 329       1    1        1     5     5  ...         3          3         4  14  14
# 318       1    1        2     1     4  ...         3          3         0  11  11
# 317       1    1        1     3     3  ...         3          3         9   9  10
# 65        1    1        1     5     4  ...         4          2         2  16  15
# 59        1    1        1     4     3  ...         2          2         2  15  16
#
# [5 rows x 11 columns]
#     school  sex  address  Mjob  Fjob  ...  freetime  studytime  absences  G1  G2
# 9        1    2        1     3     3  ...         5          2         0  14  15
# 25       1    1        1     4     4  ...         2          1        14   6   9
# 28       1    2        1     4     3  ...         3          2         4  11  11
# 31       1    2        1     4     4  ...         3          2         0  17  16
# ...

# %%
print(testFeatures.shape)
# Out:
# (79, 11)
